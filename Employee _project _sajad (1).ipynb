# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings("ignore")

# %%
df=pd.read_csv("Employee.csv")
df
# Out:
#       Education  JoiningYear       City  PaymentTier  Age  Gender EverBenched  \
# 0     Bachelors         2017  Bangalore            3   34    Male          No
# 1     Bachelors         2013       Pune            1   28  Female          No
# 2     Bachelors         2014  New Delhi            3   38  Female          No
# 3       Masters         2016  Bangalore            3   27    Male          No
# 4       Masters         2017       Pune            3   24    Male         Yes
# ...         ...          ...        ...          ...  ...     ...         ...
# 4648  Bachelors         2013  Bangalore            3   26  Female          No
# 4649    Masters         2013       Pune            2   37    Male          No
# 4650    Masters         2018  New Delhi            3   27    Male          No
# 4651  Bachelors         2012  Bangalore            3   30    Male         Yes
# 4652  Bachelors         2015  Bangalore            3   33    Male         Yes
#
# ...

# %%
df.columns
# Out:
# Index(['Education', 'JoiningYear', 'City', 'PaymentTier', 'Age', 'Gender',
#        'EverBenched', 'ExperienceInCurrentDomain', 'LeaveOrNot'],
#       dtype='object')

# %%
df.head(10)
# Out:
#    Education  JoiningYear       City  PaymentTier  Age  Gender EverBenched  \
# 0  Bachelors         2017  Bangalore            3   34    Male          No
# 1  Bachelors         2013       Pune            1   28  Female          No
# 2  Bachelors         2014  New Delhi            3   38  Female          No
# 3    Masters         2016  Bangalore            3   27    Male          No
# 4    Masters         2017       Pune            3   24    Male         Yes
# 5  Bachelors         2016  Bangalore            3   22    Male          No
# 6  Bachelors         2015  New Delhi            3   38    Male          No
# 7  Bachelors         2016  Bangalore            3   34  Female          No
# 8  Bachelors         2016       Pune            3   23    Male          No
# 9    Masters         2017  New Delhi            2   37    Male          No
#
#    ExperienceInCurrentDomain  LeaveOrNot
# 0                          0           0
# 1                          3           1
# ...

# %%
df.tail(10)
# Out:
#       Education  JoiningYear       City  PaymentTier  Age  Gender EverBenched  \
# 4643  Bachelors         2013  Bangalore            3   31  Female          No
# 4644  Bachelors         2015       Pune            3   32  Female         Yes
# 4645    Masters         2017       Pune            2   31  Female          No
# 4646  Bachelors         2013  Bangalore            3   25  Female          No
# 4647  Bachelors         2016       Pune            3   30    Male          No
# 4648  Bachelors         2013  Bangalore            3   26  Female          No
# 4649    Masters         2013       Pune            2   37    Male          No
# 4650    Masters         2018  New Delhi            3   27    Male          No
# 4651  Bachelors         2012  Bangalore            3   30    Male         Yes
# 4652  Bachelors         2015  Bangalore            3   33    Male         Yes
#
#       ExperienceInCurrentDomain  LeaveOrNot
# 4643                          5           0
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4653 entries, 0 to 4652
# Data columns (total 9 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   Education                  4653 non-null   object
#  1   JoiningYear                4653 non-null   int64
#  2   City                       4653 non-null   object
#  3   PaymentTier                4653 non-null   int64
#  4   Age                        4653 non-null   int64
#  5   Gender                     4653 non-null   object
#  6   EverBenched                4653 non-null   object
#  7   ExperienceInCurrentDomain  4653 non-null   int64
#  8   LeaveOrNot                 4653 non-null   int64
# dtypes: int64(5), object(4)
# memory usage: 327.3+ KB

# %%
df.describe()
# Out:
#        JoiningYear  PaymentTier          Age  ExperienceInCurrentDomain  \
# count  4653.000000  4653.000000  4653.000000                4653.000000
# mean   2015.062970     2.698259    29.393295                   2.905652
# std       1.863377     0.561435     4.826087                   1.558240
# min    2012.000000     1.000000    22.000000                   0.000000
# 25%    2013.000000     3.000000    26.000000                   2.000000
# 50%    2015.000000     3.000000    28.000000                   3.000000
# 75%    2017.000000     3.000000    32.000000                   4.000000
# max    2018.000000     3.000000    41.000000                   7.000000
#
#         LeaveOrNot
# count  4653.000000
# mean      0.343864
# std       0.475047
# min       0.000000
# 25%       0.000000
# 50%       0.000000
# 75%       1.000000
# max       1.000000

# %%
df.nunique()
# Out:
# Education                     3
# JoiningYear                   7
# City                          3
# PaymentTier                   3
# Age                          20
# Gender                        2
# EverBenched                   2
# ExperienceInCurrentDomain     8
# LeaveOrNot                    2
# dtype: int64

# %%
df.dtypes
# Out:
# Education                    object
# JoiningYear                   int64
# City                         object
# PaymentTier                   int64
# Age                           int64
# Gender                       object
# EverBenched                  object
# ExperienceInCurrentDomain     int64
# LeaveOrNot                    int64
# dtype: object

# %%
df.describe(include="int64")
# Out:
#        JoiningYear  PaymentTier          Age  ExperienceInCurrentDomain  \
# count  4653.000000  4653.000000  4653.000000                4653.000000
# mean   2015.062970     2.698259    29.393295                   2.905652
# std       1.863377     0.561435     4.826087                   1.558240
# min    2012.000000     1.000000    22.000000                   0.000000
# 25%    2013.000000     3.000000    26.000000                   2.000000
# 50%    2015.000000     3.000000    28.000000                   3.000000
# 75%    2017.000000     3.000000    32.000000                   4.000000
# max    2018.000000     3.000000    41.000000                   7.000000
#
#         LeaveOrNot
# count  4653.000000
# mean      0.343864
# std       0.475047
# min       0.000000
# 25%       0.000000
# 50%       0.000000
# 75%       1.000000
# max       1.000000

# %%
df.describe(include="object")
# Out:
#         Education       City Gender EverBenched
# count        4653       4653   4653        4653
# unique          3          3      2           2
# top     Bachelors  Bangalore   Male          No
# freq         3601       2228   2778        4175

# %%
df.shape
# Out:
# (4653, 9)

# %%
df.isnull().sum()
# Out:
# Education                    0
# JoiningYear                  0
# City                         0
# PaymentTier                  0
# Age                          0
# Gender                       0
# EverBenched                  0
# ExperienceInCurrentDomain    0
# LeaveOrNot                   0
# dtype: int64

# %%
df.dropna()
# Out:
#       Education  JoiningYear       City  PaymentTier  Age  Gender EverBenched  \
# 0     Bachelors         2017  Bangalore            3   34    Male          No
# 1     Bachelors         2013       Pune            1   28  Female          No
# 2     Bachelors         2014  New Delhi            3   38  Female          No
# 3       Masters         2016  Bangalore            3   27    Male          No
# 4       Masters         2017       Pune            3   24    Male         Yes
# ...         ...          ...        ...          ...  ...     ...         ...
# 4648  Bachelors         2013  Bangalore            3   26  Female          No
# 4649    Masters         2013       Pune            2   37    Male          No
# 4650    Masters         2018  New Delhi            3   27    Male          No
# 4651  Bachelors         2012  Bangalore            3   30    Male         Yes
# 4652  Bachelors         2015  Bangalore            3   33    Male         Yes
#
# ...

# %%
df.duplicated()
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 4648     True
# 4649    False
# 4650    False
# 4651    False
# 4652     True
# Length: 4653, dtype: bool

# %%
df.drop_duplicates()
print(df.to_string())
# Out:
#       Education  JoiningYear       City  PaymentTier  Age  Gender EverBenched  ExperienceInCurrentDomain  LeaveOrNot
# 0     Bachelors         2017  Bangalore            3   34    Male          No                          0           0
# 1     Bachelors         2013       Pune            1   28  Female          No                          3           1
# 2     Bachelors         2014  New Delhi            3   38  Female          No                          2           0
# 3       Masters         2016  Bangalore            3   27    Male          No                          5           1
# 4       Masters         2017       Pune            3   24    Male         Yes                          2           1
# 5     Bachelors         2016  Bangalore            3   22    Male          No                          0           0
# 6     Bachelors         2015  New Delhi            3   38    Male          No                          0           0
# ...

# %%
df.drop_duplicates(inplace=True)
df
# Out:
#       Education  JoiningYear       City  PaymentTier  Age  Gender EverBenched  \
# 0     Bachelors         2017  Bangalore            3   34    Male          No
# 1     Bachelors         2013       Pune            1   28  Female          No
# 2     Bachelors         2014  New Delhi            3   38  Female          No
# 3       Masters         2016  Bangalore            3   27    Male          No
# 4       Masters         2017       Pune            3   24    Male         Yes
# ...         ...          ...        ...          ...  ...     ...         ...
# 4645    Masters         2017       Pune            2   31  Female          No
# 4647  Bachelors         2016       Pune            3   30    Male          No
# 4649    Masters         2013       Pune            2   37    Male          No
# 4650    Masters         2018  New Delhi            3   27    Male          No
# 4651  Bachelors         2012  Bangalore            3   30    Male         Yes
#
# ...

# %% [markdown]
# # Visualization of Data

# %%
plt.figure(figsize=(12, 6))
sns.histplot(df['Age'], bins=50, kde=True,color='red')
plt.xlabel('Age')
plt.ylabel('People')
plt.title('Histogram of Age Distribution')
plt.show()

# %%
plt.figure(figsize=(12, 6))
sns.histplot(df['City'], bins=50, kde=True,color='blue')
plt.xlabel('City')
plt.ylabel('People')
plt.title('Histogram of City Distribution')
plt.show()

# %%
sns.countplot(x = 'Gender', data = df, palette = 'magma')
plt.title("Gender_plot")
plt.show()

# %%
labels = ['Yes', 'No']
custom_colors = ['blue', 'red']
plt.pie(df.EverBenched.value_counts(), labels=labels, autopct='%.1f%%',colors=custom_colors)
plt.title("EverBenched")
plt.show()

# %%
sns.countplot(x = 'Education', data = df, palette = 'PuRd')
plt.title("Education")
plt.show()

# %%
sns.countplot(x = 'JoiningYear', data = df, palette = 'bright')
plt.title("JoiningYear")
plt.show()

# %%
sns.countplot(x = 'PaymentTier', data = df, palette = 'dark')
plt.title("PaymentTier")
plt.show()

# %%
labels = ['Yes', 'No']
custom_colors = ['yellow', 'red']
plt.pie(df.LeaveOrNot.value_counts(), labels=labels, autopct='%.1f%%',colors=custom_colors)
plt.title("LeaveOrNot")
plt.show()

# %% [markdown]
# # Correlation

# %%
corr=df.corr()
corr
# Out:
#                            JoiningYear  PaymentTier       Age  \
# JoiningYear                   1.000000    -0.053823  0.024445
# PaymentTier                  -0.053823     1.000000  0.067514
# Age                           0.024445     0.067514  1.000000
# ExperienceInCurrentDomain    -0.031228    -0.004602 -0.053276
# LeaveOrNot                    0.150650    -0.119891 -0.114943
#
#                            ExperienceInCurrentDomain  LeaveOrNot
# JoiningYear                                -0.031228    0.150650
# PaymentTier                                -0.004602   -0.119891
# Age                                        -0.053276   -0.114943
# ExperienceInCurrentDomain                   1.000000   -0.021181
# LeaveOrNot                                 -0.021181    1.000000

# %% [markdown]
# # Heatmap

# %%
corr=df.corr()

sns.heatmap(corr,annot=True,linewidths=.5,cmap="coolwarm")
# Out:
# <Axes: >

# %%
# pairplot

# %%
sns.pairplot(df, vars=["JoiningYear", "Age", "ExperienceInCurrentDomain"])
plt.show()

# %%
plt.figure(figsize=(20, 6))
sns.barplot(x='JoiningYear', y='ExperienceInCurrentDomain', data=df, palette = 'dark')
plt.title('ExperienceInCurrentDomain vs JoiningYear')

plt.xticks(rotation=45)
plt.show()

# %% [markdown]
# # Machine Learning

# %%
x=df.drop(['LeaveOrNot'],axis=1)
x
# Out:
#       Education  JoiningYear       City  PaymentTier  Age  Gender EverBenched  \
# 0     Bachelors         2017  Bangalore            3   34    Male          No
# 1     Bachelors         2013       Pune            1   28  Female          No
# 2     Bachelors         2014  New Delhi            3   38  Female          No
# 3       Masters         2016  Bangalore            3   27    Male          No
# 4       Masters         2017       Pune            3   24    Male         Yes
# ...         ...          ...        ...          ...  ...     ...         ...
# 4645    Masters         2017       Pune            2   31  Female          No
# 4647  Bachelors         2016       Pune            3   30    Male          No
# 4649    Masters         2013       Pune            2   37    Male          No
# 4650    Masters         2018  New Delhi            3   27    Male          No
# 4651  Bachelors         2012  Bangalore            3   30    Male         Yes
#
#       ExperienceInCurrentDomain
# ...

# %%
y = df['LeaveOrNot']
y
# Out:
# 0       0
# 1       1
# 2       0
# 3       1
# 4       1
#        ..
# 4645    0
# 4647    0
# 4649    1
# 4650    1
# 4651    0
# Name: LeaveOrNot, Length: 2764, dtype: int64

# %%
from sklearn.model_selection import train_test_split

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.33,random_state=42)

# %%
x_train.shape,x_test.shape
# Out:
# ((1851, 8), (913, 8))

# %%
x_train.head()
# Out:
#       Education  JoiningYear       City  PaymentTier  Age  Gender EverBenched  \
# 3437    Masters         2014       Pune            3   39    Male          No
# 3290  Bachelors         2013  Bangalore            2   38  Female          No
# 3947  Bachelors         2015  Bangalore            3   34  Female          No
# 311   Bachelors         2017  Bangalore            3   24  Female          No
# 2533  Bachelors         2015  New Delhi            3   28  Female          No
#
#       ExperienceInCurrentDomain
# 3437                          4
# 3290                          1
# 3947                          2
# 311                           2
# 2533                          4

# %%
# pip install --upgrade category_encoders

# %%
import category_encoders as ce

encoder = ce.OrdinalEncoder(cols=['Education', 'JoiningYear', 'City', 'PaymentTier', 'Age', 'Gender','EverBenched','ExperienceInCurrentDomain'])

# %%
x_train= encoder.fit_transform(x_train)

# %%
x_test=encoder.transform(x_test)

# %%
x_train.head()
# Out:
#       Education  JoiningYear  City  PaymentTier  Age  Gender  EverBenched  \
# 3437          1            1     1            1    1       1            1
# 3290          2            2     2            2    2       2            1
# 3947          2            3     2            1    3       2            1
# 311           2            4     2            1    4       2            1
# 2533          2            3     3            1    5       2            1
#
#       ExperienceInCurrentDomain
# 3437                          1
# 3290                          2
# 3947                          3
# 311                           3
# 2533                          1

# %% [markdown]
# # RandomForest

# %%
from sklearn.ensemble import RandomForestClassifier

# %%
rfc = RandomForestClassifier(n_estimators=10,random_state=0)

# %%
# fit the model
rfc.fit(x_train,y_train)
# Out:
# RandomForestClassifier(n_estimators=10, random_state=0)

# %%
#predict
y_pred=rfc.predict(x_test)

# %%
from sklearn.metrics import accuracy_score

# %%
accuracy = accuracy_score(y_test, y_pred)
print("Accuracy:", accuracy * 100)
# Out:
# Accuracy: 71.19386637458926

# %%
from sklearn.metrics import classification_report, confusion_matrix

# %%
print("Confusion Matrix: ")
print(confusion_matrix(y_test, y_pred))

print("Classification Report :")
print(classification_report(y_test, y_pred))
# Out:
# Confusion Matrix:
# [[443  94]
#  [169 207]]
# Classification Report :
#               precision    recall  f1-score   support
#
#            0       0.72      0.82      0.77       537
#            1       0.69      0.55      0.61       376
#
#     accuracy                           0.71       913
#    macro avg       0.71      0.69      0.69       913
# weighted avg       0.71      0.71      0.71       913

# %%
from sklearn.metrics import precision_score
precision = precision_score(y_test, y_pred, average='micro')  # You can choose 'micro', 'macro', 'weighted', or 'None'
print("Precision:", precision)
# Out:
# Precision: 0.7119386637458927

# %%
from sklearn.metrics import recall_score
recall = recall_score(y_test, y_pred, average='micro')  # You can choose 'micro', 'macro', 'weighted', or 'None'
print("Recall:", recall)
# Out:
# Recall: 0.7119386637458927

# %% [markdown]
#  # logistic regression

# %%
from sklearn.model_selection import train_test_split

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.33,random_state=42)

# %%
x_train.shape,x_test.shape
# Out:
# ((1851, 8), (913, 8))

# %%
import category_encoders as ce

encoder = ce.OrdinalEncoder(cols=['Education', 'JoiningYear', 'City', 'PaymentTier', 'Age', 'Gender','EverBenched','ExperienceInCurrentDomain'])

# %%
x_train= encoder.fit_transform(x_train)

# %%
x_test=encoder.transform(x_test)

# %%
x_train.head()
# Out:
#       Education  JoiningYear  City  PaymentTier  Age  Gender  EverBenched  \
# 3437          1            1     1            1    1       1            1
# 3290          2            2     2            2    2       2            1
# 3947          2            3     2            1    3       2            1
# 311           2            4     2            1    4       2            1
# 2533          2            3     3            1    5       2            1
#
#       ExperienceInCurrentDomain
# 3437                          1
# 3290                          2
# 3947                          3
# 311                           3
# 2533                          1

# %%
from sklearn.linear_model import LogisticRegression

# %%
le = LogisticRegression()

# %%
le.fit(x_train, y_train)
# Out:
# LogisticRegression()

# %%
y_pred = le.predict(x_test)

# %%
accuracy = accuracy_score(y_test,y_pred)
print('Accuracy: %.2f' % (accuracy*100))
# Out:
# Accuracy: 65.39

# %%
print("Confusion Matrix: ")
print(confusion_matrix(y_test, y_pred))

print("Classification Report :")
print(classification_report(y_test, y_pred))
# Out:
# Confusion Matrix:
# [[455  82]
#  [234 142]]
# Classification Report :
#               precision    recall  f1-score   support
#
#            0       0.66      0.85      0.74       537
#            1       0.63      0.38      0.47       376
#
#     accuracy                           0.65       913
#    macro avg       0.65      0.61      0.61       913
# weighted avg       0.65      0.65      0.63       913

# %%
precision = precision_score(y_test, y_pred, average='micro')  # You can choose 'micro', 'macro', 'weighted', or 'None'
print("Precision:", precision)
# Out:
# Precision: 0.6538882803943045

# %%
recall = recall_score(y_test, y_pred, average='micro')  # You can choose 'micro', 'macro', 'weighted', or 'None'
print("Recall:", recall)
# Out:
# Recall: 0.6538882803943045

# %% [markdown]
# # KNN

# %%
from sklearn.neighbors import KNeighborsClassifier

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.33,random_state=42)

# %%
x_train.shape,x_test.shape
# Out:
# ((1851, 8), (913, 8))

# %%
import category_encoders as ce

encoder = ce.OrdinalEncoder(cols=['Education', 'JoiningYear', 'City', 'PaymentTier', 'Age', 'Gender','EverBenched','ExperienceInCurrentDomain'])

# %%
x_train= encoder.fit_transform(x_train)

# %%
x_test=encoder.transform(x_test)

# %%
x_train.head()
# Out:
#       Education  JoiningYear  City  PaymentTier  Age  Gender  EverBenched  \
# 3437          1            1     1            1    1       1            1
# 3290          2            2     2            2    2       2            1
# 3947          2            3     2            1    3       2            1
# 311           2            4     2            1    4       2            1
# 2533          2            3     3            1    5       2            1
#
#       ExperienceInCurrentDomain
# 3437                          1
# 3290                          2
# 3947                          3
# 311                           3
# 2533                          1

# %%
kn = KNeighborsClassifier(n_neighbors=7)

# %%
kn.fit(x_train, y_train)
# Out:
# KNeighborsClassifier(n_neighbors=7)

# %%
y_pred = kn.predict(x_test)

# %%
accuracy = accuracy_score(y_test, y_pred)
print("Accuracy:", accuracy * 100)
# Out:
# Accuracy: 63.74589266155532

# %%
print("Confusion Matrix: ")
print(confusion_matrix(y_test, y_pred))

print("Classification Report :")
print(classification_report(y_test, y_pred))
# Out:
# Confusion Matrix:
# [[433 104]
#  [227 149]]
# Classification Report :
#               precision    recall  f1-score   support
#
#            0       0.66      0.81      0.72       537
#            1       0.59      0.40      0.47       376
#
#     accuracy                           0.64       913
#    macro avg       0.62      0.60      0.60       913
# weighted avg       0.63      0.64      0.62       913

# %%
precision = precision_score(y_test, y_pred, average='micro')  # You can choose 'micro', 'macro', 'weighted', or 'None'
print("Precision:", precision)
# Out:
# Precision: 0.6374589266155531

# %%
recall = recall_score(y_test, y_pred, average='micro')  # You can choose 'micro', 'macro', 'weighted', or 'None'
print("Recall:", recall)
# Out:
# Recall: 0.6374589266155531

# %% [markdown]
# # Decision tree

# %%
from sklearn.tree import DecisionTreeClassifier

# %%
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.33, random_state=42)

# %%
x_train.shape,x_test.shape
# Out:
# ((1851, 8), (913, 8))

# %%
import category_encoders as ce

encoder = ce.OrdinalEncoder(cols=['Education', 'JoiningYear', 'City', 'PaymentTier', 'Age', 'Gender','EverBenched','ExperienceInCurrentDomain'])

# %%
x_train= encoder.fit_transform(x_train)

# %%
x_test=encoder.transform(x_test)

# %%
x_train.head()
# Out:
#       Education  JoiningYear  City  PaymentTier  Age  Gender  EverBenched  \
# 3437          1            1     1            1    1       1            1
# 3290          2            2     2            2    2       2            1
# 3947          2            3     2            1    3       2            1
# 311           2            4     2            1    4       2            1
# 2533          2            3     3            1    5       2            1
#
#       ExperienceInCurrentDomain
# 3437                          1
# 3290                          2
# 3947                          3
# 311                           3
# 2533                          1

# %%
dtree = DecisionTreeClassifier()

# %%
dtree.fit(x_train, y_train)
# Out:
# DecisionTreeClassifier()

# %%
y_pred = dtree.predict(x_test)

# %%
accuracy = accuracy_score(y_test, y_pred)
print("Accuracy:", accuracy * 100)
# Out:
# Accuracy: 66.37458926615552

# %%
print("Confusion Matrix: ")
print(confusion_matrix(y_test, y_pred))

print("Classification Report :")
print(classification_report(y_test, y_pred))
# Out:
# Confusion Matrix:
# [[385 152]
#  [155 221]]
# Classification Report :
#               precision    recall  f1-score   support
#
#            0       0.71      0.72      0.71       537
#            1       0.59      0.59      0.59       376
#
#     accuracy                           0.66       913
#    macro avg       0.65      0.65      0.65       913
# weighted avg       0.66      0.66      0.66       913

# %%
precision = precision_score(y_test, y_pred, average='micro')  # You can choose 'micro', 'macro', 'weighted', or 'None'
print("Precision:", precision)
# Out:
# Precision: 0.6637458926615553

# %%
recall = recall_score(y_test, y_pred, average='micro')  # You can choose 'micro', 'macro', 'weighted', or 'None'
print("Recall:", recall)
# Out:
# Recall: 0.6637458926615553

# %% [markdown]
# # Support Vector Machine

# %%
from sklearn.svm import SVC

# %%
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.33, random_state=42)

# %%
x_train.shape,x_test.shape
# Out:
# ((1851, 8), (913, 8))

# %%
import category_encoders as ce

encoder = ce.OrdinalEncoder(cols=['Education', 'JoiningYear', 'City', 'PaymentTier', 'Age', 'Gender','EverBenched','ExperienceInCurrentDomain'])

# %%
x_train= encoder.fit_transform(x_train)

# %%
x_test=encoder.transform(x_test)

# %%
x_train.head()
# Out:
#       Education  JoiningYear  City  PaymentTier  Age  Gender  EverBenched  \
# 3437          1            1     1            1    1       1            1
# 3290          2            2     2            2    2       2            1
# 3947          2            3     2            1    3       2            1
# 311           2            4     2            1    4       2            1
# 2533          2            3     3            1    5       2            1
#
#       ExperienceInCurrentDomain
# 3437                          1
# 3290                          2
# 3947                          3
# 311                           3
# 2533                          1

# %%
svc=SVC().fit(x_train, y_train)

# %%
y_pred = svc.predict(x_test)

# %%
accuracy = accuracy_score(y_test, y_pred)
print("Accuracy:", accuracy * 100)
# Out:
# Accuracy: 62.10295728368017

# %%
print("Confusion Matrix: ")
print(confusion_matrix(y_test, y_pred))

print("Classification Report :")
print(classification_report(y_test, y_pred))
# Out:
# Confusion Matrix:
# [[504  33]
#  [313  63]]
# Classification Report :
#               precision    recall  f1-score   support
#
#            0       0.62      0.94      0.74       537
#            1       0.66      0.17      0.27       376
#
#     accuracy                           0.62       913
#    macro avg       0.64      0.55      0.51       913
# weighted avg       0.63      0.62      0.55       913

# %%
precision = precision_score(y_test, y_pred, average='micro')  # You can choose 'micro', 'macro', 'weighted', or 'None'
print("Precision:", precision)
# Out:
# Precision: 0.6210295728368017

# %%
recall = recall_score(y_test, y_pred, average='micro')  # You can choose 'micro', 'macro', 'weighted', or 'None'
print("Recall:", recall)
# Out:
# Recall: 0.6210295728368017

# %% [markdown]
# # All Model Accuracy Graph

# %%
# Initialize classifiers
classifiers = {
    "Logistic Regression": LogisticRegression(),
    "Random Forest": RandomForestClassifier(n_estimators=10),
    "K-Nearest Neighbors": KNeighborsClassifier(n_neighbors=7),
    "Decision Tree": DecisionTreeClassifier(),
    "Support Vector Machine": SVC(),
}

# Define a list of colors
colors = ['blue', 'green', 'red', 'purple', 'orange']

# Train and evaluate each classifier
accuracy_scores = {}
fig, ax = plt.subplots()
for i, (name, clf) in enumerate(classifiers.items()):
    clf.fit(x_train, y_train)
    y_pred = clf.predict(x_test)
    accuracy = accuracy_score(y_test, y_pred)
    accuracy_scores[name] = accuracy

    # Set a different color for each bar
    ax.bar(name, accuracy, color=colors[i])

plt.xticks(rotation=45)
plt.ylabel("Accuracy")
plt.title("Classifier Accuracy Comparison")
plt.show()
